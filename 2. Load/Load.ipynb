-- %% [markdown]
-- # [Olist_Post_ETL]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Olist_Post_ETL]    Script Date: 22/06/2025 19:37:18 ******/
CREATE DATABASE [Olist_Post_ETL]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'olist_datware', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER2022\MSSQL\DATA\olist_datware.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'olist_datware_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER2022\MSSQL\DATA\olist_datware_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Olist_Post_ETL] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Olist_Post_ETL].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Olist_Post_ETL] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET ARITHABORT OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Olist_Post_ETL] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Olist_Post_ETL] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Olist_Post_ETL] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Olist_Post_ETL] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET RECOVERY FULL 
GO
ALTER DATABASE [Olist_Post_ETL] SET  MULTI_USER 
GO
ALTER DATABASE [Olist_Post_ETL] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Olist_Post_ETL] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Olist_Post_ETL] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Olist_Post_ETL] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Olist_Post_ETL] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Olist_Post_ETL] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Olist_Post_ETL', N'ON'
GO
ALTER DATABASE [Olist_Post_ETL] SET QUERY_STORE = ON
GO
ALTER DATABASE [Olist_Post_ETL] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[customerDim]

-- %%
USE [Olist_Post_ETL]
GO

-- %%
/****** Object:  Table [dbo].[customerDim]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[customerDim](
	[customer_zip_code_prefix] [varchar](50) NULL,
	[customer_id] [varchar](50) NULL,
	[geolocation_lat] [varchar](50) NULL,
	[geolocation_lng] [varchar](50) NULL,
	[geolocation_state] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactorderItem]

-- %%
/****** Object:  Table [dbo].[FactorderItem]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactorderItem](
	[order_id] [varchar](50) NULL,
	[order_item_id] [varchar](50) NULL,
	[product_id] [varchar](50) NULL,
	[seller_id] [varchar](50) NULL,
	[shipping_limit_date] [datetime] NULL,
	[price] [float] NULL,
	[freight_value] [float] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[orderDim]

-- %%
/****** Object:  Table [dbo].[orderDim]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[orderDim](
	[customer_id] [varchar](50) NULL,
	[order_id] [varchar](50) NULL,
	[order_status] [varchar](50) NULL,
	[order_purchase_timestamp] [datetime] NULL,
	[order_approved_at] [datetime] NULL,
	[order_delivered_carrier_date] [datetime] NULL,
	[order_delivered_customer_date] [datetime] NULL,
	[order_estimated_delivery_date] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[paymentDim]

-- %%
/****** Object:  Table [dbo].[paymentDim]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[paymentDim](
	[order_id] [varchar](50) NULL,
	[payment_sequential] [numeric](18, 0) NULL,
	[payment_type] [varchar](50) NULL,
	[payment_installments] [numeric](18, 0) NULL,
	[payment_value] [real] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[productDim]

-- %%
/****** Object:  Table [dbo].[productDim]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[productDim](
	[product_id] [varchar](50) NULL,
	[product_weight_g] [numeric](18, 0) NULL,
	[product_length_cm] [numeric](18, 0) NULL,
	[product_height_cm] [numeric](18, 0) NULL,
	[product_width_cm] [numeric](18, 0) NULL,
	[product_category_name_english] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sellerDim]

-- %%
/****** Object:  Table [dbo].[sellerDim]    Script Date: 22/06/2025 19:37:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sellerDim](
	[seller_zip_code_prefix] [varchar](50) NULL,
	[seller_id] [varchar](50) NULL,
	[geolocation_lat] [varchar](50) NULL,
	[geolocation_lng] [varchar](50) NULL,
	[geolocation_state] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [Olist_Post_ETL]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Olist_Post_ETL] SET  READ_WRITE 
GO
